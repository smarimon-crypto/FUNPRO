# %% [markdown]
# # Saludando al mundo

# %%
Nombre=input("Cuál es tu nombre?")
# Out:
# Cuál es tu nombre?Sneyder

# %%
print("Hello world 🤠")
# Out:
#   File "/tmp/ipykernel_828/252676648.py", line 1
#     2print("Hello world 🤠")
#     ^
# SyntaxError: invalid decimal literal

# %%
#CONCATENACIÓN: Unir dos tipos de datos
print("Hola" ,Nombre)
# Out:
# Hola Sneyder

# %%
print(f"Hola {Nombre}")
# Out:
# Hola Sneyder
